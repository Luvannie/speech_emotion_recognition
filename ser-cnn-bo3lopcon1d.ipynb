# %%
#IMPORT THE LIBRARIES
import pandas as pd
import numpy as np

import os
import sys

# librosa is a Python library for analyzing audio and music. It can be used to extract the data from the audio files we will see it later.
import librosa
import librosa.display
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

# to play the audio files
import IPython.display as ipd
from IPython.display import Audio
import keras
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Embedding
from keras.layers import LSTM,BatchNormalization , GRU,Attention
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from keras.layers import Input, Flatten, Dropout, Activation
from keras.layers import Conv1D, MaxPooling1D, AveragePooling1D
from keras.models import Model
from keras.callbacks import ModelCheckpoint, EarlyStopping,ReduceLROnPlateau
from tensorflow.keras.optimizers import SGD
import warnings
import pickle
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning) 
import tensorflow as tf 
print ("Done")
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Done

# %%
Emotions = pd.read_csv('/kaggle/input/speech-emotion/emotion.csv')

# %%
print(Emotions.isna().any())
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 2372         True
# 2373         True
# 2374         True
# 2375         True
# Emotions    False
# Length: 2377, dtype: bool

# %%
Emotions=Emotions.fillna(0)
print(Emotions.isna().any())
Emotions.shape
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 2372        False
# 2373        False
# 2374        False
# 2375        False
# Emotions    False
# Length: 2377, dtype: bool
# (46728, 2377)

# %%
np.sum(Emotions.isna())
# Out:
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
#            ..
# 2372        0
# 2373        0
# 2374        0
# 2375        0
# Emotions    0
# Length: 2377, dtype: int64

# %% [markdown]
# # Data Prepare

# %%
Y=Emotions['Emotions']
X= Emotions.drop('Emotions',axis= 1)

# %%
X.shape
# Out:
# (46728, 2376)

# %%
Y.shape
# Out:
# (46728,)

# %%
encoder = OneHotEncoder()
Y = encoder.fit_transform(np.array(Y).reshape(-1,1)).toarray()

# %%
with open('encoder.pkl', 'wb') as f:
    pickle.dump(encoder, f)

# %%
#train test split
x_train, x_test, y_train, y_test = train_test_split(X, Y, random_state=35,test_size=0.2, shuffle=True)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((37382, 2376), (37382, 7), (9346, 2376), (9346, 7))

# %%
#reshape for lstm
X_train = x_train.to_numpy().reshape(x_train.shape[0] , x_train.shape[1] , 1)
X_test = x_test.to_numpy().reshape(x_test.shape[0] , x_test.shape[1] , 1)

# %%
# scale data
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.fit_transform(x_test)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((37382, 2376), (37382, 7), (9346, 2376), (9346, 7))

# %%
with open('scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)

# %%
model_checkpoint = ModelCheckpoint('best_model_local_weights.h5', monitor='val_accuracy', save_best_only=True)
early_stop=EarlyStopping(monitor='val_acc',mode='auto',patience=5,restore_best_weights=True)
lr_reduction=ReduceLROnPlateau(monitor='val_acc',patience=5,verbose=1,factor=0.5,min_lr=0.00001)

# %% [markdown]
# # CNN model

# %%
#Reshape for CNN_LSTM MODEL

x_traincnn =np.expand_dims(x_train, axis=2)
x_testcnn= np.expand_dims(x_test, axis=2)
x_traincnn.shape, y_train.shape, x_testcnn.shape, y_test.shape
#x_testcnn[0]
# Out:
# ((37382, 2376, 1), (37382, 7), (9346, 2376, 1), (9346, 7))

# %%
import tensorflow.keras.layers as L

model = tf.keras.Sequential([
    L.Conv1D(512,kernel_size=5, strides=1,padding='same', activation='relu',input_shape=(X_train.shape[1],1)),
    L.BatchNormalization(),
    L.MaxPool1D(pool_size=5,strides=2,padding='same'),
    
#     L.Conv1D(512,kernel_size=5,strides=1,padding='same',activation='relu'),
#     L.BatchNormalization(),
#     L.MaxPool1D(pool_size=5,strides=2,padding='same'),
#     Dropout(0.2),  # Add dropout layer after the second max pooling layer
    
#     L.Conv1D(256,kernel_size=5,strides=1,padding='same',activation='relu'),
#     L.BatchNormalization(),
#     L.MaxPool1D(pool_size=5,strides=2,padding='same'),
    
#     L.Conv1D(256,kernel_size=3,strides=1,padding='same',activation='relu'),
#     L.BatchNormalization(),
#     L.MaxPool1D(pool_size=5,strides=2,padding='same'),
#     Dropout(0.2),  # Add dropout layer after the fourth max pooling layer
    
    L.Conv1D(128,kernel_size=3,strides=1,padding='same',activation='relu'),
    L.BatchNormalization(),
    L.MaxPool1D(pool_size=3,strides=2,padding='same'),
    Dropout(0.2),  # Add dropout layer after the fifth max pooling layer
    
    L.Flatten(),
    L.Dense(512,activation='relu'),
    L.BatchNormalization(),
    L.Dense(7,activation='softmax')
])
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics='accuracy')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 2376, 512)         3072
#
#  batch_normalization (Batch  (None, 2376, 512)         2048
#  Normalization)
#
#  max_pooling1d (MaxPooling1  (None, 1188, 512)         0
#  D)
#
#  conv1d_1 (Conv1D)           (None, 1188, 128)         196736
#
#  batch_normalization_1 (Bat  (None, 1188, 128)         512
#  chNormalization)
#
#  max_pooling1d_1 (MaxPoolin  (None, 594, 128)          0
#  g1D)
#
#  dropout (Dropout)           (None, 594, 128)          0
#
#  flatten (Flatten)           (None, 76032)             0
#
#  dense (Dense)               (None, 512)               38928896
#
#  batch_normalization_2 (Bat  (None, 512)               2048
#  chNormalization)
#
#  dense_1 (Dense)             (None, 7)                 3591
#
# =================================================================
# Total params: 39136903 (149.30 MB)
# Trainable params: 39134599 (149.29 MB)
# Non-trainable params: 2304 (9.00 KB)
# _________________________________________________________________

# %%
history=model.fit(x_traincnn, y_train, epochs=50, validation_data=(x_testcnn, y_test), batch_size=128,callbacks=[early_stop,lr_reduction,model_checkpoint])
# Out:
# Epoch 1/50
# 293/293 [==============================] - 56s 158ms/step - loss: 1.5268 - accuracy: 0.4474 - val_loss: 4.7325 - val_accuracy: 0.2068 - lr: 0.0010
# Epoch 2/50
# 293/293 [==============================] - 46s 156ms/step - loss: 1.0746 - accuracy: 0.5880 - val_loss: 1.4153 - val_accuracy: 0.4864 - lr: 0.0010
# Epoch 3/50
# 293/293 [==============================] - 46s 156ms/step - loss: 0.8869 - accuracy: 0.6657 - val_loss: 1.6516 - val_accuracy: 0.4942 - lr: 0.0010
# Epoch 4/50
# 293/293 [==============================] - 46s 156ms/step - loss: 0.7426 - accuracy: 0.7210 - val_loss: 0.9746 - val_accuracy: 0.6371 - lr: 0.0010
# Epoch 5/50
# 293/293 [==============================] - 46s 156ms/step - loss: 0.5006 - accuracy: 0.8190 - val_loss: 0.8659 - val_accuracy: 0.6850 - lr: 0.0010
# Epoch 6/50
# 293/293 [==============================] - 46s 156ms/step - loss: 0.3142 - accuracy: 0.8924 - val_loss: 0.6376 - val_accuracy: 0.7772 - lr: 0.0010
# Epoch 7/50
# 293/293 [==============================] - 46s 156ms/step - loss: 0.1658 - accuracy: 0.9481 - val_loss: 0.5128 - val_accuracy: 0.8334 - lr: 0.0010
# Epoch 8/50
# 293/293 [==============================] - 46s 156ms/step - loss: 0.0925 - accuracy: 0.9734 - val_loss: 0.5084 - val_accuracy: 0.8439 - lr: 0.0010
# Epoch 9/50
# 293/293 [==============================] - 46s 156ms/step - loss: 0.0725 - accuracy: 0.9786 - val_loss: 0.4228 - val_accuracy: 0.8580 - lr: 0.0010
# Epoch 10/50
# 293/293 [==============================] - 46s 156ms/step - loss: 0.0356 - accuracy: 0.9915 - val_loss: 0.3288 - val_accuracy: 0.8974 - lr: 0.0010
# Epoch 11/50
# 293/293 [==============================] - 44s 152ms/step - loss: 0.0363 - accuracy: 0.9907 - val_loss: 0.3684 - val_accuracy: 0.8847 - lr: 0.0010
# Epoch 12/50
# 293/293 [==============================] - 44s 152ms/step - loss: 0.0807 - accuracy: 0.9743 - val_loss: 0.4600 - val_accuracy: 0.8656 - lr: 0.0010
# Epoch 13/50
# 293/293 [==============================] - 44s 152ms/step - loss: 0.0705 - accuracy: 0.9771 - val_loss: 0.4292 - val_accuracy: 0.8630 - lr: 0.0010
# Epoch 14/50
# 293/293 [==============================] - 44s 152ms/step - loss: 0.0420 - accuracy: 0.9885 - val_loss: 0.3956 - val_accuracy: 0.8751 - lr: 0.0010
# Epoch 15/50
# 293/293 [==============================] - 44s 152ms/step - loss: 0.4212 - accuracy: 0.8561 - val_loss: 0.6007 - val_accuracy: 0.8167 - lr: 0.0010
# Epoch 16/50
# 293/293 [==============================] - 44s 152ms/step - loss: 0.1661 - accuracy: 0.9436 - val_loss: 0.4058 - val_accuracy: 0.8675 - lr: 0.0010
# Epoch 17/50
# 293/293 [==============================] - 44s 152ms/step - loss: 0.1717 - accuracy: 0.9417 - val_loss: 0.3137 - val_accuracy: 0.8948 - lr: 0.0010
# Epoch 18/50
# 293/293 [==============================] - 46s 156ms/step - loss: 0.0385 - accuracy: 0.9892 - val_loss: 0.2781 - val_accuracy: 0.9131 - lr: 0.0010
# Epoch 19/50
# 293/293 [==============================] - 46s 156ms/step - loss: 0.0237 - accuracy: 0.9948 - val_loss: 0.2353 - val_accuracy: 0.9299 - lr: 0.0010
# Epoch 20/50
# 293/293 [==============================] - 44s 152ms/step - loss: 0.0331 - accuracy: 0.9901 - val_loss: 0.2431 - val_accuracy: 0.9242 - lr: 0.0010
# Epoch 21/50
# 293/293 [==============================] - 44s 152ms/step - loss: 0.0212 - accuracy: 0.9944 - val_loss: 0.2532 - val_accuracy: 0.9240 - lr: 0.0010
# Epoch 22/50
# 293/293 [==============================] - 44s 152ms/step - loss: 0.0278 - accuracy: 0.9920 - val_loss: 0.2881 - val_accuracy: 0.9127 - lr: 0.0010
# Epoch 23/50
# 293/293 [==============================] - 44s 152ms/step - loss: 0.0476 - accuracy: 0.9850 - val_loss: 0.3214 - val_accuracy: 0.9043 - lr: 0.0010
# Epoch 24/50
# 293/293 [==============================] - 44s 152ms/step - loss: 0.0925 - accuracy: 0.9692 - val_loss: 0.3032 - val_accuracy: 0.9039 - lr: 0.0010
# Epoch 25/50
# 293/293 [==============================] - 46s 156ms/step - loss: 0.0337 - accuracy: 0.9896 - val_loss: 0.2326 - val_accuracy: 0.9331 - lr: 0.0010
# Epoch 26/50
# 293/293 [==============================] - 44s 152ms/step - loss: 0.0183 - accuracy: 0.9949 - val_loss: 0.2396 - val_accuracy: 0.9305 - lr: 0.0010
# Epoch 27/50
# 293/293 [==============================] - 44s 152ms/step - loss: 0.0236 - accuracy: 0.9930 - val_loss: 0.2509 - val_accuracy: 0.9327 - lr: 0.0010
# Epoch 28/50
# 293/293 [==============================] - 46s 156ms/step - loss: 0.0175 - accuracy: 0.9952 - val_loss: 0.2193 - val_accuracy: 0.9373 - lr: 0.0010
# Epoch 29/50
# 293/293 [==============================] - 46s 156ms/step - loss: 0.0095 - accuracy: 0.9975 - val_loss: 0.1974 - val_accuracy: 0.9435 - lr: 0.0010
# Epoch 30/50
# 293/293 [==============================] - 44s 152ms/step - loss: 0.0069 - accuracy: 0.9983 - val_loss: 0.2262 - val_accuracy: 0.9352 - lr: 0.0010
# Epoch 31/50
# 293/293 [==============================] - 44s 152ms/step - loss: 0.0150 - accuracy: 0.9955 - val_loss: 0.4677 - val_accuracy: 0.8905 - lr: 0.0010
# Epoch 32/50
# 293/293 [==============================] - 44s 152ms/step - loss: 0.0598 - accuracy: 0.9803 - val_loss: 0.3379 - val_accuracy: 0.9100 - lr: 0.0010
# Epoch 33/50
# 293/293 [==============================] - 44s 152ms/step - loss: 0.0378 - accuracy: 0.9883 - val_loss: 0.7391 - val_accuracy: 0.7972 - lr: 0.0010
# Epoch 34/50
# 293/293 [==============================] - 44s 152ms/step - loss: 0.0561 - accuracy: 0.9810 - val_loss: 0.3399 - val_accuracy: 0.9019 - lr: 0.0010
# Epoch 35/50
# 293/293 [==============================] - 44s 152ms/step - loss: 0.0386 - accuracy: 0.9873 - val_loss: 0.2767 - val_accuracy: 0.9205 - lr: 0.0010
# Epoch 36/50
# 293/293 [==============================] - 44s 152ms/step - loss: 0.0138 - accuracy: 0.9959 - val_loss: 0.2333 - val_accuracy: 0.9358 - lr: 0.0010
# Epoch 37/50
# 293/293 [==============================] - 44s 152ms/step - loss: 0.0135 - accuracy: 0.9963 - val_loss: 0.2605 - val_accuracy: 0.9317 - lr: 0.0010
# Epoch 38/50
# 293/293 [==============================] - 44s 152ms/step - loss: 0.0123 - accuracy: 0.9965 - val_loss: 0.3473 - val_accuracy: 0.9078 - lr: 0.0010
# Epoch 39/50
# 293/293 [==============================] - 44s 152ms/step - loss: 0.2312 - accuracy: 0.9284 - val_loss: 0.3497 - val_accuracy: 0.8993 - lr: 0.0010
# Epoch 40/50
# 293/293 [==============================] - 44s 152ms/step - loss: 0.0257 - accuracy: 0.9924 - val_loss: 0.2781 - val_accuracy: 0.9175 - lr: 0.0010
# Epoch 41/50
# 293/293 [==============================] - 44s 152ms/step - loss: 0.0406 - accuracy: 0.9869 - val_loss: 0.2608 - val_accuracy: 0.9248 - lr: 0.0010
# Epoch 42/50
# 293/293 [==============================] - 44s 152ms/step - loss: 0.0230 - accuracy: 0.9929 - val_loss: 0.2529 - val_accuracy: 0.9292 - lr: 0.0010
# Epoch 43/50
# 293/293 [==============================] - 44s 152ms/step - loss: 0.0099 - accuracy: 0.9974 - val_loss: 0.2212 - val_accuracy: 0.9363 - lr: 0.0010
# Epoch 44/50
# 293/293 [==============================] - 44s 152ms/step - loss: 0.0061 - accuracy: 0.9987 - val_loss: 0.2302 - val_accuracy: 0.9398 - lr: 0.0010
# Epoch 45/50
# 293/293 [==============================] - 44s 152ms/step - loss: 0.0101 - accuracy: 0.9975 - val_loss: 0.2314 - val_accuracy: 0.9367 - lr: 0.0010
# Epoch 46/50
# 293/293 [==============================] - 44s 152ms/step - loss: 0.0066 - accuracy: 0.9983 - val_loss: 0.2389 - val_accuracy: 0.9319 - lr: 0.0010
# Epoch 47/50
# 293/293 [==============================] - 44s 152ms/step - loss: 0.0099 - accuracy: 0.9976 - val_loss: 0.2476 - val_accuracy: 0.9317 - lr: 0.0010
# Epoch 48/50
# 293/293 [==============================] - 44s 152ms/step - loss: 0.0071 - accuracy: 0.9979 - val_loss: 0.2713 - val_accuracy: 0.9283 - lr: 0.0010
# Epoch 49/50
# 293/293 [==============================] - 44s 152ms/step - loss: 0.0941 - accuracy: 0.9704 - val_loss: 0.3499 - val_accuracy: 0.9023 - lr: 0.0010
# Epoch 50/50
# 293/293 [==============================] - 45s 152ms/step - loss: 0.0199 - accuracy: 0.9937 - val_loss: 0.4952 - val_accuracy: 0.8767 - lr: 0.0010

# %%
print("Accuracy of our model on test data : " , model.evaluate(x_testcnn,y_test)[1]*100 , "%")

epochs = [i for i in range(50)]
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
test_acc = history.history['val_accuracy']
test_loss = history.history['val_loss']

fig.set_size_inches(20,6)
ax[0].plot(epochs , train_loss , label = 'Training Loss')
ax[0].plot(epochs , test_loss , label = 'Testing Loss')
ax[0].set_title('Training & Testing Loss')
ax[0].legend()
ax[0].set_xlabel("Epochs")

ax[1].plot(epochs , train_acc , label = 'Training Accuracy')
ax[1].plot(epochs , test_acc , label = 'Testing Accuracy')
ax[1].set_title('Training & Testing Accuracy')
ax[1].legend()
ax[1].set_xlabel("Epochs")
plt.show()
# Out:
# 293/293 [==============================] - 4s 12ms/step - loss: 0.4952 - accuracy: 0.8767
# Accuracy of our model on test data :  87.67387270927429 %

# %%
# predicting on test data.
pred_test0 = model.predict(x_testcnn)
y_pred0 = encoder.inverse_transform(pred_test0)
y_test0 = encoder.inverse_transform(y_test)

# Check for random predictions
df0 = pd.DataFrame(columns=['Predicted Labels', 'Actual Labels'])
df0['Predicted Labels'] = y_pred0.flatten()
df0['Actual Labels'] = y_test0.flatten()

df0.head(10)
# Out:
# 293/293 [==============================] - 3s 10ms/step
#   Predicted Labels Actual Labels
# 0             fear          fear
# 1          neutral       neutral
# 2         surprise      surprise
# 3              sad           sad
# 4          neutral       neutral
# 5            happy         happy
# 6             fear          fear
# 7              sad       disgust
# 8         surprise      surprise
# 9            angry         angry
