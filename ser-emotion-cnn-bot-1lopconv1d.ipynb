# %%
#IMPORT THE LIBRARIES
import pandas as pd
import numpy as np

import os
import sys

# librosa is a Python library for analyzing audio and music. It can be used to extract the data from the audio files we will see it later.
import librosa
import librosa.display
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

# to play the audio files
import IPython.display as ipd
from IPython.display import Audio
import keras
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Embedding
from keras.layers import LSTM,BatchNormalization , GRU,Attention
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from keras.layers import Input, Flatten, Dropout, Activation
from keras.layers import Conv1D, MaxPooling1D, AveragePooling1D
from keras.models import Model
from keras.callbacks import ModelCheckpoint, EarlyStopping,ReduceLROnPlateau
from tensorflow.keras.optimizers import SGD
import warnings
import pickle
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning) 
import tensorflow as tf 
print ("Done")
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Done

# %%
Emotions = pd.read_csv('/kaggle/input/speech-emotion/emotion.csv')

# %%
print(Emotions.isna().any())
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 2372         True
# 2373         True
# 2374         True
# 2375         True
# Emotions    False
# Length: 2377, dtype: bool

# %%
Emotions=Emotions.fillna(0)
print(Emotions.isna().any())
Emotions.shape
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 2372        False
# 2373        False
# 2374        False
# 2375        False
# Emotions    False
# Length: 2377, dtype: bool
# (46728, 2377)

# %%
np.sum(Emotions.isna())
# Out:
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
#            ..
# 2372        0
# 2373        0
# 2374        0
# 2375        0
# Emotions    0
# Length: 2377, dtype: int64

# %% [markdown]
# # Data Prepare

# %%
Y=Emotions['Emotions']
X= Emotions.drop('Emotions',axis= 1)

# %%
X.shape
# Out:
# (46728, 2376)

# %%
Y.shape
# Out:
# (46728,)

# %%
encoder = OneHotEncoder()
Y = encoder.fit_transform(np.array(Y).reshape(-1,1)).toarray()

# %%
with open('encoder.pkl', 'wb') as f:
    pickle.dump(encoder, f)

# %%
#train test split
x_train, x_test, y_train, y_test = train_test_split(X, Y, random_state=35,test_size=0.2, shuffle=True)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((37382, 2376), (37382, 7), (9346, 2376), (9346, 7))

# %%
#reshape for lstm
X_train = x_train.to_numpy().reshape(x_train.shape[0] , x_train.shape[1] , 1)
X_test = x_test.to_numpy().reshape(x_test.shape[0] , x_test.shape[1] , 1)

# %%
# scale data
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.fit_transform(x_test)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((37382, 2376), (37382, 7), (9346, 2376), (9346, 7))

# %%
with open('scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)

# %%
model_checkpoint = ModelCheckpoint('best_model_local_weights.h5', monitor='val_accuracy', save_best_only=True)
early_stop=EarlyStopping(monitor='val_acc',mode='auto',patience=5,restore_best_weights=True)
lr_reduction=ReduceLROnPlateau(monitor='val_acc',patience=5,verbose=1,factor=0.5,min_lr=0.00001)

# %% [markdown]
# LSTM Model

# %% [markdown]
# # CNN model

# %%
#Reshape for CNN_LSTM MODEL

x_traincnn =np.expand_dims(x_train, axis=2)
x_testcnn= np.expand_dims(x_test, axis=2)
x_traincnn.shape, y_train.shape, x_testcnn.shape, y_test.shape
#x_testcnn[0]
# Out:
# ((37382, 2376, 1), (37382, 7), (9346, 2376, 1), (9346, 7))

# %%
import tensorflow.keras.layers as L

model = tf.keras.Sequential([
    L.Conv1D(512,kernel_size=5, strides=1,padding='same', activation='relu',input_shape=(X_train.shape[1],1)),
    L.BatchNormalization(),
    L.MaxPool1D(pool_size=5,strides=2,padding='same'),
    
#     L.Conv1D(512,kernel_size=5,strides=1,padding='same',activation='relu'),
#     L.BatchNormalization(),
#     L.MaxPool1D(pool_size=5,strides=2,padding='same'),
#     Dropout(0.2),  # Add dropout layer after the second max pooling layer
    
    L.Conv1D(256,kernel_size=5,strides=1,padding='same',activation='relu'),
    L.BatchNormalization(),
    L.MaxPool1D(pool_size=5,strides=2,padding='same'),
    
    L.Conv1D(256,kernel_size=3,strides=1,padding='same',activation='relu'),
    L.BatchNormalization(),
    L.MaxPool1D(pool_size=5,strides=2,padding='same'),
    Dropout(0.2),  # Add dropout layer after the fourth max pooling layer
    
    L.Conv1D(128,kernel_size=3,strides=1,padding='same',activation='relu'),
    L.BatchNormalization(),
    L.MaxPool1D(pool_size=3,strides=2,padding='same'),
    Dropout(0.2),  # Add dropout layer after the fifth max pooling layer
    
    L.Flatten(),
    L.Dense(512,activation='relu'),
    L.BatchNormalization(),
    L.Dense(7,activation='softmax')
])
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics='accuracy')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 2376, 512)         3072
#
#  batch_normalization (Batch  (None, 2376, 512)         2048
#  Normalization)
#
#  max_pooling1d (MaxPooling1  (None, 1188, 512)         0
#  D)
#
#  conv1d_1 (Conv1D)           (None, 1188, 256)         655616
#
#  batch_normalization_1 (Bat  (None, 1188, 256)         1024
#  chNormalization)
#
#  max_pooling1d_1 (MaxPoolin  (None, 594, 256)          0
#  g1D)
#
#  conv1d_2 (Conv1D)           (None, 594, 256)          196864
#
#  batch_normalization_2 (Bat  (None, 594, 256)          1024
#  chNormalization)
#
#  max_pooling1d_2 (MaxPoolin  (None, 297, 256)          0
#  g1D)
#
#  dropout (Dropout)           (None, 297, 256)          0
#
#  conv1d_3 (Conv1D)           (None, 297, 128)          98432
#
#  batch_normalization_3 (Bat  (None, 297, 128)          512
#  chNormalization)
#
#  max_pooling1d_3 (MaxPoolin  (None, 149, 128)          0
#  g1D)
#
#  dropout_1 (Dropout)         (None, 149, 128)          0
#
#  flatten (Flatten)           (None, 19072)             0
#
#  dense (Dense)               (None, 512)               9765376
#
#  batch_normalization_4 (Bat  (None, 512)               2048
#  chNormalization)
#
#  dense_1 (Dense)             (None, 7)                 3591
#
# =================================================================
# Total params: 10729607 (40.93 MB)
# Trainable params: 10726279 (40.92 MB)
# Non-trainable params: 3328 (13.00 KB)
# _________________________________________________________________

# %%
history=model.fit(x_traincnn, y_train, epochs=50, validation_data=(x_testcnn, y_test), batch_size=128,callbacks=[early_stop,lr_reduction,model_checkpoint])
# Out:
# Epoch 1/50
# 293/293 [==============================] - 78s 223ms/step - loss: 1.3762 - accuracy: 0.4830 - val_loss: 3.4501 - val_accuracy: 0.2096 - lr: 0.0010
# Epoch 2/50
# 293/293 [==============================] - 64s 220ms/step - loss: 1.0546 - accuracy: 0.5917 - val_loss: 1.2879 - val_accuracy: 0.5090 - lr: 0.0010
# Epoch 3/50
# 293/293 [==============================] - 64s 220ms/step - loss: 0.9303 - accuracy: 0.6431 - val_loss: 0.9962 - val_accuracy: 0.6145 - lr: 0.0010
# Epoch 4/50
# 293/293 [==============================] - 64s 220ms/step - loss: 0.7948 - accuracy: 0.6969 - val_loss: 1.0142 - val_accuracy: 0.6152 - lr: 0.0010
# Epoch 5/50
# 293/293 [==============================] - 64s 220ms/step - loss: 0.6306 - accuracy: 0.7661 - val_loss: 0.9830 - val_accuracy: 0.6429 - lr: 0.0010
# Epoch 6/50
# 293/293 [==============================] - 64s 218ms/step - loss: 0.5855 - accuracy: 0.7823 - val_loss: 1.4398 - val_accuracy: 0.5458 - lr: 0.0010
# Epoch 7/50
# 293/293 [==============================] - 64s 220ms/step - loss: 0.6815 - accuracy: 0.7468 - val_loss: 0.7379 - val_accuracy: 0.7253 - lr: 0.0010
# Epoch 8/50
# 293/293 [==============================] - 64s 218ms/step - loss: 0.3337 - accuracy: 0.8853 - val_loss: 1.1490 - val_accuracy: 0.6264 - lr: 0.0010
# Epoch 9/50
# 293/293 [==============================] - 64s 220ms/step - loss: 0.2272 - accuracy: 0.9269 - val_loss: 0.3960 - val_accuracy: 0.8637 - lr: 0.0010
# Epoch 10/50
# 293/293 [==============================] - 64s 220ms/step - loss: 0.1639 - accuracy: 0.9478 - val_loss: 0.2858 - val_accuracy: 0.9025 - lr: 0.0010
# Epoch 11/50
# 293/293 [==============================] - 64s 220ms/step - loss: 0.0799 - accuracy: 0.9779 - val_loss: 0.2407 - val_accuracy: 0.9179 - lr: 0.0010
# Epoch 12/50
# 293/293 [==============================] - 64s 218ms/step - loss: 0.0985 - accuracy: 0.9700 - val_loss: 0.3707 - val_accuracy: 0.8726 - lr: 0.0010
# Epoch 13/50
# 293/293 [==============================] - 64s 218ms/step - loss: 0.1104 - accuracy: 0.9642 - val_loss: 0.8169 - val_accuracy: 0.7367 - lr: 0.0010
# Epoch 14/50
# 293/293 [==============================] - 64s 218ms/step - loss: 0.2907 - accuracy: 0.9033 - val_loss: 0.4466 - val_accuracy: 0.8408 - lr: 0.0010
# Epoch 15/50
# 293/293 [==============================] - 64s 218ms/step - loss: 0.1513 - accuracy: 0.9506 - val_loss: 0.2693 - val_accuracy: 0.9097 - lr: 0.0010
# Epoch 16/50
# 293/293 [==============================] - 64s 218ms/step - loss: 0.1312 - accuracy: 0.9576 - val_loss: 0.2788 - val_accuracy: 0.9147 - lr: 0.0010
# Epoch 17/50
# 293/293 [==============================] - 64s 220ms/step - loss: 0.0615 - accuracy: 0.9815 - val_loss: 0.1691 - val_accuracy: 0.9437 - lr: 0.0010
# Epoch 18/50
# 293/293 [==============================] - 64s 220ms/step - loss: 0.0210 - accuracy: 0.9956 - val_loss: 0.1472 - val_accuracy: 0.9522 - lr: 0.0010
# Epoch 19/50
# 293/293 [==============================] - 64s 218ms/step - loss: 0.0206 - accuracy: 0.9951 - val_loss: 0.1605 - val_accuracy: 0.9481 - lr: 0.0010
# Epoch 20/50
# 293/293 [==============================] - 64s 220ms/step - loss: 0.0253 - accuracy: 0.9936 - val_loss: 0.1515 - val_accuracy: 0.9526 - lr: 0.0010
# Epoch 21/50
# 293/293 [==============================] - 64s 218ms/step - loss: 0.0289 - accuracy: 0.9918 - val_loss: 0.1931 - val_accuracy: 0.9393 - lr: 0.0010
# Epoch 22/50
# 293/293 [==============================] - 64s 218ms/step - loss: 0.0571 - accuracy: 0.9820 - val_loss: 0.2116 - val_accuracy: 0.9385 - lr: 0.0010
# Epoch 23/50
# 293/293 [==============================] - 64s 218ms/step - loss: 0.0531 - accuracy: 0.9824 - val_loss: 0.2099 - val_accuracy: 0.9370 - lr: 0.0010
# Epoch 24/50
# 293/293 [==============================] - 64s 218ms/step - loss: 0.0273 - accuracy: 0.9917 - val_loss: 0.3553 - val_accuracy: 0.8969 - lr: 0.0010
# Epoch 25/50
# 293/293 [==============================] - 64s 218ms/step - loss: 0.0815 - accuracy: 0.9730 - val_loss: 0.2201 - val_accuracy: 0.9348 - lr: 0.0010
# Epoch 26/50
# 293/293 [==============================] - 64s 218ms/step - loss: 0.0425 - accuracy: 0.9861 - val_loss: 0.2138 - val_accuracy: 0.9342 - lr: 0.0010
# Epoch 27/50
# 293/293 [==============================] - 64s 218ms/step - loss: 0.0337 - accuracy: 0.9898 - val_loss: 0.3090 - val_accuracy: 0.9062 - lr: 0.0010
# Epoch 28/50
# 293/293 [==============================] - 64s 218ms/step - loss: 0.1674 - accuracy: 0.9462 - val_loss: 0.2151 - val_accuracy: 0.9303 - lr: 0.0010
# Epoch 29/50
# 293/293 [==============================] - 64s 218ms/step - loss: 0.0259 - accuracy: 0.9923 - val_loss: 0.1742 - val_accuracy: 0.9491 - lr: 0.0010
# Epoch 30/50
# 293/293 [==============================] - 64s 218ms/step - loss: 0.0148 - accuracy: 0.9961 - val_loss: 0.1655 - val_accuracy: 0.9496 - lr: 0.0010
# Epoch 31/50
# 293/293 [==============================] - 64s 220ms/step - loss: 0.0166 - accuracy: 0.9951 - val_loss: 0.1631 - val_accuracy: 0.9539 - lr: 0.0010
# Epoch 32/50
# 293/293 [==============================] - 64s 218ms/step - loss: 0.0488 - accuracy: 0.9845 - val_loss: 0.2687 - val_accuracy: 0.9170 - lr: 0.0010
# Epoch 33/50
# 293/293 [==============================] - 64s 218ms/step - loss: 0.1180 - accuracy: 0.9605 - val_loss: 0.2258 - val_accuracy: 0.9343 - lr: 0.0010
# Epoch 34/50
# 293/293 [==============================] - 64s 218ms/step - loss: 0.0283 - accuracy: 0.9911 - val_loss: 0.1507 - val_accuracy: 0.9536 - lr: 0.0010
# Epoch 35/50
# 293/293 [==============================] - 64s 218ms/step - loss: 0.0381 - accuracy: 0.9876 - val_loss: 0.1600 - val_accuracy: 0.9525 - lr: 0.0010
# Epoch 36/50
# 293/293 [==============================] - 64s 218ms/step - loss: 0.0259 - accuracy: 0.9923 - val_loss: 0.1556 - val_accuracy: 0.9537 - lr: 0.0010
# Epoch 37/50
# 293/293 [==============================] - 64s 220ms/step - loss: 0.0095 - accuracy: 0.9977 - val_loss: 0.1299 - val_accuracy: 0.9626 - lr: 0.0010
# Epoch 38/50
# 293/293 [==============================] - 64s 220ms/step - loss: 0.0061 - accuracy: 0.9987 - val_loss: 0.1273 - val_accuracy: 0.9631 - lr: 0.0010
# Epoch 39/50
# 293/293 [==============================] - 64s 218ms/step - loss: 0.0053 - accuracy: 0.9989 - val_loss: 0.1393 - val_accuracy: 0.9584 - lr: 0.0010
# Epoch 40/50
# 293/293 [==============================] - 64s 218ms/step - loss: 0.0454 - accuracy: 0.9845 - val_loss: 0.1849 - val_accuracy: 0.9489 - lr: 0.0010
# Epoch 41/50
# 293/293 [==============================] - 64s 218ms/step - loss: 0.0172 - accuracy: 0.9946 - val_loss: 0.2042 - val_accuracy: 0.9418 - lr: 0.0010
# Epoch 42/50
# 293/293 [==============================] - 64s 218ms/step - loss: 0.0872 - accuracy: 0.9718 - val_loss: 0.1835 - val_accuracy: 0.9475 - lr: 0.0010
# Epoch 43/50
# 293/293 [==============================] - 64s 218ms/step - loss: 0.0148 - accuracy: 0.9957 - val_loss: 0.1603 - val_accuracy: 0.9540 - lr: 0.0010
# Epoch 44/50
# 293/293 [==============================] - 64s 218ms/step - loss: 0.0150 - accuracy: 0.9955 - val_loss: 0.1451 - val_accuracy: 0.9573 - lr: 0.0010
# Epoch 45/50
# 293/293 [==============================] - 64s 218ms/step - loss: 0.0096 - accuracy: 0.9974 - val_loss: 0.1738 - val_accuracy: 0.9525 - lr: 0.0010
# Epoch 46/50
# 293/293 [==============================] - 64s 218ms/step - loss: 0.0243 - accuracy: 0.9927 - val_loss: 0.2821 - val_accuracy: 0.9191 - lr: 0.0010
# Epoch 47/50
# 293/293 [==============================] - 64s 218ms/step - loss: 0.1207 - accuracy: 0.9613 - val_loss: 0.3017 - val_accuracy: 0.9139 - lr: 0.0010
# Epoch 48/50
# 293/293 [==============================] - 64s 218ms/step - loss: 0.2612 - accuracy: 0.9231 - val_loss: 0.2375 - val_accuracy: 0.9280 - lr: 0.0010
# Epoch 49/50
# 293/293 [==============================] - 64s 218ms/step - loss: 0.0652 - accuracy: 0.9784 - val_loss: 0.1947 - val_accuracy: 0.9387 - lr: 0.0010
# Epoch 50/50
# 293/293 [==============================] - 64s 218ms/step - loss: 0.0175 - accuracy: 0.9953 - val_loss: 0.1495 - val_accuracy: 0.9559 - lr: 0.0010

# %%
print("Accuracy of our model on test data : " , model.evaluate(x_testcnn,y_test)[1]*100 , "%")

epochs = [i for i in range(50)]
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
test_acc = history.history['val_accuracy']
test_loss = history.history['val_loss']

fig.set_size_inches(20,6)
ax[0].plot(epochs , train_loss , label = 'Training Loss')
ax[0].plot(epochs , test_loss , label = 'Testing Loss')
ax[0].set_title('Training & Testing Loss')
ax[0].legend()
ax[0].set_xlabel("Epochs")

ax[1].plot(epochs , train_acc , label = 'Training Accuracy')
ax[1].plot(epochs , test_acc , label = 'Testing Accuracy')
ax[1].set_title('Training & Testing Accuracy')
ax[1].legend()
ax[1].set_xlabel("Epochs")
plt.show()
# Out:
# 293/293 [==============================] - 5s 17ms/step - loss: 0.1495 - accuracy: 0.9559
# Accuracy of our model on test data :  95.59169411659241 %

# %%
# predicting on test data.
pred_test0 = model.predict(x_testcnn)
y_pred0 = encoder.inverse_transform(pred_test0)
y_test0 = encoder.inverse_transform(y_test)

# Check for random predictions
df0 = pd.DataFrame(columns=['Predicted Labels', 'Actual Labels'])
df0['Predicted Labels'] = y_pred0.flatten()
df0['Actual Labels'] = y_test0.flatten()

df0.head(10)
# Out:
# 293/293 [==============================] - 5s 15ms/step
#   Predicted Labels Actual Labels
# 0             fear          fear
# 1          neutral       neutral
# 2         surprise      surprise
# 3              sad           sad
# 4          neutral       neutral
# 5            happy         happy
# 6             fear          fear
# 7          disgust       disgust
# 8         surprise      surprise
# 9            angry         angry
